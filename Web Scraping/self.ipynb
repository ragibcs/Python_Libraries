# %%
# !pip install requests
# !pip install bs4
# !pip install lxml
# Out:
# Requirement already satisfied: requests in /home/mondal/miniconda3/envs/ineuron/lib/python3.10/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mondal/miniconda3/envs/ineuron/lib/python3.10/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mondal/miniconda3/envs/ineuron/lib/python3.10/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mondal/miniconda3/envs/ineuron/lib/python3.10/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mondal/miniconda3/envs/ineuron/lib/python3.10/site-packages (from requests) (2026.1.4)
# Requirement already satisfied: bs4 in /home/mondal/miniconda3/envs/ineuron/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /home/mondal/miniconda3/envs/ineuron/lib/python3.10/site-packages (from bs4) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/mondal/miniconda3/envs/ineuron/lib/python3.10/site-packages (from beautifulsoup4->bs4) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/mondal/miniconda3/envs/ineuron/lib/python3.10/site-packages (from beautifulsoup4->bs4) (4.15.0)
# Collecting lxml
#   Downloading lxml-6.0.2-cp310-cp310-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Downloading lxml-6.0.2-cp310-cp310-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 10.3 MB/s  0:00:00 10.8 MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

page_count = 1

while True:
    URL = f"https://quotes.toscrape.com/page/{page_count}/"
    res = requests.get(URL)
    soup = BeautifulSoup(res.text, "html.parser")  # changed

    quotes = soup.select("div.quote")
    if not quotes:
        print("No valid pages anymore")
        break
    
    with open(f"scraped_data/quotes{page_count}.html","w") as f:
        f.write(res.text)
        print(f"Downloaded data from page {page_count}")
    page_count=page_count+1
# Out:
# Downloaded data from page 1
# Downloaded data from page 2
# Downloaded data from page 3
# Downloaded data from page 4
# Downloaded data from page 5
# Downloaded data from page 6
# Downloaded data from page 7
# Downloaded data from page 8
# Downloaded data from page 9
# Downloaded data from page 10
# No valid pages anymore

# %%
#extract useful info from page 1
with open("scraped_data/quotes1.html","r") as f:
    html_content=f.read()
soup= BeautifulSoup(html_content,"html.parser")
# all_quotes=soup.select("div.quote")
# print(all_quotes)

# %%
all_quotes=soup.select("div.quote")
for q in all_quotes:
    all_tags=q.select(".tags .tag")
    # print(all_tags)
    for tag in q.select(".tags .tag"):
        all_tags.append(tag.get_text())
        print(tag.get_text())
    print(all_tags)
# Out:
# change
# deep-thoughts
# thinking
# world
# [<a class="tag" href="/tag/change/page/1/">change</a>, <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>, <a class="tag" href="/tag/thinking/page/1/">thinking</a>, <a class="tag" href="/tag/world/page/1/">world</a>, 'change', 'deep-thoughts', 'thinking', 'world']
# abilities
# choices
# [<a class="tag" href="/tag/abilities/page/1/">abilities</a>, <a class="tag" href="/tag/choices/page/1/">choices</a>, 'abilities', 'choices']
# inspirational
# life
# live
# miracle
# miracles
# [<a class="tag" href="/tag/inspirational/page/1/">inspirational</a>, <a class="tag" href="/tag/life/page/1/">life</a>, <a class="tag" href="/tag/live/page/1/">live</a>, <a class="tag" href="/tag/miracle/page/1/">miracle</a>, <a class="tag" href="/tag/miracles/page/1/">miracles</a>, 'inspirational', 'life', 'live', 'miracle', 'miracles']
# aliteracy
# books
# classic
# humor
# [<a class="tag" href="/tag/aliteracy/page/1/">aliteracy</a>, <a class="tag" href="/tag/books/page/1/">books</a>, <a class="tag" href="/tag/classic/page/1/">classic</a>, <a class="tag" href="/tag/humor/page/1/">humor</a>, 'aliteracy', 'books', 'classic', 'humor']
# be-yourself
# inspirational
# [<a class="tag" href="/tag/be-yourself/page/1/">be-yourself</a>, <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>, 'be-yourself', 'inspirational']
# adulthood
# success
# value
# [<a class="tag" href="/tag/adulthood/page/1/">adulthood</a>, <a class="tag" href="/tag/success/page/1/">success</a>, <a class="tag" href="/tag/value/page/1/">value</a>, 'adulthood', 'success', 'value']
# life
# love
# [<a class="tag" href="/tag/life/page/1/">life</a>, <a class="tag" href="/tag/love/page/1/">love</a>, 'life', 'love']
# edison
# failure
# inspirational
# paraphrased
# [<a class="tag" href="/tag/edison/page/1/">edison</a>, <a class="tag" href="/tag/failure/page/1/">failure</a>, <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>, <a class="tag" href="/tag/paraphrased/page/1/">paraphrased</a>, 'edison', 'failure', 'inspirational', 'paraphrased']
# misattributed-eleanor-roosevelt
# [<a class="tag" href="/tag/misattributed-eleanor-roosevelt/page/1/">misattributed-eleanor-roosevelt</a>, 'misattributed-eleanor-roosevelt']
# humor
# obvious
# simile
# [<a class="tag" href="/tag/humor/page/1/">humor</a>, <a class="tag" href="/tag/obvious/page/1/">obvious</a>, <a class="tag" href="/tag/simile/page/1/">simile</a>, 'humor', 'obvious', 'simile']
