# %%
import matplotlib.pyplot as plt
X=[1,2,3,4]
Y=[5,6,7,8]
plt.plot(X,Y)
plt.show()

# %%
# Movies Data

# Oscar Winner Movies
oscar_movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
oscar_years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M
#plot
plt.plot(oscar_years,oscar_revenue)
plt.title("Oscar movies revenue")
plt.xlabel("year")
plt.ylabel("revenue")
# Out:
# Text(0, 0.5, 'revenue')

# %%
# Plot multiple
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M
plt.plot(oscar_years,oscar_revenue,"o--r",label="Oskar Winners")
plt.plot(non_oscar_years,non_oscar_revenue,"<-y",label="Non- Oskar Winners")
plt.title("Oskar movies revenue vs Non Oskar revenue")
plt.xlabel("years")
plt.ylabel("Revenue")
plt.legend()

# %%
with plt.xkcd():    
        plt.plot(oscar_years,oscar_revenue,label="Oskar Winners")
        plt.plot(non_oscar_years,non_oscar_revenue,label="Non- Oskar Winners")
        plt.title("Oskar movies revenue vs Non Oskar revenue")
        plt.xlabel("years")
        plt.ylabel("Revenue")
        plt.legend()
        # print(plt.style.available)
        # plt.style.use("default")
        # plt.grid()
        plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %%
#movies -- revenue

# Movies Data

# Oscar Winner Movies
movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232]  # in $M
#plot
plt.style.use("default")
plt.plot(movies,revenue)
plt.title("Movies Revenue")
plt.xlabel("Movies")
plt.ylabel("Revenue($M)")
plt.tight_layout()
plt.savefig("final_plot.png")

# %%
import matplotlib.pyplot as plt

# %%
movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232]  # in $M
plt.bar(years,revenue,color="yellow")
plt.title("Revenue in each Year")
plt.xlabel("year")
plt.ylabel("Revenue in million")
for i in range(len(years)):
    plt.text(years[i],revenue[i]+20,str(revenue[i]),ha="center")
plt.ylim(0,max(revenue)+100)
# plt.xlim(min(years),max(years)+2)
# Out:
# (0.0, 1105.0)

# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# ...
#   Using cached matplotlib-3.10.8-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (114 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-12.1.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 8.7 MB/s  0:00:01s eta 0:00:010:01:01
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
oskar_movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
oskar_years = [2008, 2009, 2010, 2011, 2012]
oskar_revenue = [1005, 170, 427, 133, 232]  # in $M
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

x=np.arange(len(oskar_years))

width=0.4
plt.bar(x-width/2,oskar_revenue,width,label="Oskar Movies")
plt.bar(x+width/2,non_oscar_revenue,width,label="Non Oskar movies")

plt.title("Oscar vs Non_Oskar movies")
plt.xlabel("Years")
plt.ylabel("Revenue")
plt.legend()
